# %%
import pandas as pd
df = pd.DataFrame({
    'Posisi': [0, 2, 4, 6, 8, 10],
    'Kecepatan': ['0', '10', '24', '48', '60', '66'],
    'Percepatan': ['0', '0', '18', '14', '6', '20']
})

df.rename(columns={
    'Posisi': 'Posisi benda (m)',
    'Kecepatan': 'Kecepatan Benda (m/s)',
    'Percepatan' : 'Percepatan Benda (m^2/s)'
}, inplace=True)
df
# Out:
#    Posisi benda (m) Kecepatan Benda (m/s) Percepatan Benda (m^2/s)
# 0                 0                     0                        0
# 1                 2                    10                        0
# 2                 4                    24                       18
# 3                 6                    48                       14
# 4                 8                    60                        6
# 5                10                    66                       20
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Posisi benda (m)'].plot(kind='hist', bins=20, title='Posisi benda (m)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...
